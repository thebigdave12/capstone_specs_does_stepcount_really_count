# %%
import pandas as pd

# %%
fitbit_df = pd.read_csv('fitbit_data.csv')

# %%
dave_data_df = pd.read_csv('Dave_fitbit_stats.csv')

# %%
fitbit_df
# Out:
#              Id ActivityDate ActivityDay  TotalSteps  TotalDistance  \
# 0    1503960366    4/12/2016         Tue       13162       8.500000
# 1    1503960366    4/13/2016         Wed       10735       6.970000
# 2    1503960366    4/14/2016         Thu       10460       6.740000
# 3    1503960366    4/15/2016         Fri        9762       6.280000
# 4    1503960366    4/16/2016         Sat       12669       8.160000
# ..          ...          ...         ...         ...            ...
# 935  8877689391     5/8/2016         Sun       10686       8.110000
# 936  8877689391     5/9/2016         Mon       20226      18.250000
# 937  8877689391    5/10/2016         Tue       10733       8.150000
# 938  8877689391    5/11/2016         Wed       21420      19.559999
# 939  8877689391    5/12/2016         Thu        8064       6.120000
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0           8.500000                       0.0                1.88
# 1           6.970000                       0.0                1.57
# 2           6.740000                       0.0                2.44
# 3           6.280000                       0.0                2.14
# 4           8.160000                       0.0                2.71
# ..               ...                       ...                 ...
# 935         8.110000                       0.0                1.08
# 936        18.250000                       0.0               11.10
# 937         8.150000                       0.0                1.35
# 938        19.559999                       0.0               13.22
# 939         6.120000                       0.0                1.82
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                        0.55                 6.06                     0.00
# 1                        0.69                 4.71                     0.00
# 2                        0.40                 3.91                     0.00
# 3                        1.26                 2.83                     0.00
# 4                        0.41                 5.04                     0.00
# ..                        ...                  ...                      ...
# 935                      0.20                 6.80                     0.00
# 936                      0.80                 6.24                     0.05
# 937                      0.46                 6.28                     0.00
# 938                      0.41                 5.89                     0.00
# 939                      0.04                 4.25                     0.00
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                   25                   13                   328
# 1                   21                   19                   217
# 2                   30                   11                   181
# 3                   29                   34                   209
# 4                   36                   10                   221
# ..                 ...                  ...                   ...
# 935                 17                    4                   245
# 936                 73                   19                   217
# 937                 18                   11                   224
# 938                 88                   12                   213
# 939                 23                    1                   137
#
#      SedentaryMinutes  Calories  Unnamed: 16 Unnamed: 17
# 0                 728      1985          NaN         Tue
# 1                 776      1797          NaN         Wed
# 2                1218      1776          NaN         Thu
# 3                 726      1745          NaN         Fri
# 4                 773      1863          NaN         Sat
# ..                ...       ...          ...         ...
# 935              1174      2847          NaN         Sun
# 936              1131      3710          NaN         Mon
# 937              1187      2832          NaN         Tue
# 938              1127      3832          NaN         Wed
# 939               770      1849          NaN         Thu
#
# [940 rows x 18 columns]

# %%
fitbit_df.loc[fitbit_df["TotalSteps"] == 0]
# Out:
#              Id ActivityDate ActivityDay  TotalSteps  TotalDistance  \
# 30   1503960366    5/12/2016         Thu           0            0.0
# 104  1844505072    4/24/2016         Sun           0            0.0
# 105  1844505072    4/25/2016         Mon           0            0.0
# 106  1844505072    4/26/2016         Tue           0            0.0
# 112  1844505072     5/2/2016         Mon           0            0.0
# ..          ...          ...         ...         ...            ...
# 904  8792009665     5/6/2016         Fri           0            0.0
# 905  8792009665     5/7/2016         Sat           0            0.0
# 906  8792009665     5/8/2016         Sun           0            0.0
# 907  8792009665     5/9/2016         Mon           0            0.0
# 908  8792009665    5/10/2016         Tue           0            0.0
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 30               0.0                       0.0                 0.0
# 104              0.0                       0.0                 0.0
# 105              0.0                       0.0                 0.0
# 106              0.0                       0.0                 0.0
# 112              0.0                       0.0                 0.0
# ..               ...                       ...                 ...
# 904              0.0                       0.0                 0.0
# 905              0.0                       0.0                 0.0
# 906              0.0                       0.0                 0.0
# 907              0.0                       0.0                 0.0
# 908              0.0                       0.0                 0.0
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 30                        0.0                  0.0                      0.0
# 104                       0.0                  0.0                      0.0
# 105                       0.0                  0.0                      0.0
# 106                       0.0                  0.0                      0.0
# 112                       0.0                  0.0                      0.0
# ..                        ...                  ...                      ...
# 904                       0.0                  0.0                      0.0
# 905                       0.0                  0.0                      0.0
# 906                       0.0                  0.0                      0.0
# 907                       0.0                  0.0                      0.0
# 908                       0.0                  0.0                      0.0
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 30                   0                    0                     0
# 104                  0                    0                     0
# 105                  0                    0                     0
# 106                  0                    0                     0
# 112                  0                    0                     0
# ..                 ...                  ...                   ...
# 904                  0                    0                     0
# 905                  0                    0                     0
# 906                  0                    0                     0
# 907                  0                    0                     0
# 908                  0                    0                     0
#
#      SedentaryMinutes  Calories  Unnamed: 16 Unnamed: 17
# 30               1440         0          NaN         Thu
# 104              1440      1347          NaN         Sun
# 105              1440      1347          NaN         Mon
# 106              1440      1347          NaN         Tue
# 112              1440      1348          NaN         Mon
# ..                ...       ...          ...         ...
# 904              1440      1688          NaN         Fri
# 905              1440      1688          NaN         Sat
# 906              1440      1688          NaN         Sun
# 907              1440      1688          NaN         Mon
# 908                48        57          NaN         Tue
#
# [77 rows x 18 columns]

# %%
fitbit_df["Id"].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        3372868164, 3977333714, 4020332650, 4057192912, 4319703577,
#        4388161847, 4445114986, 4558609924, 4702921684, 5553957443,
#        5577150313, 6117666160, 6290855005, 6775888955, 6962181067,
#        7007744171, 7086361926, 8053475328, 8253242879, 8378563200,
#        8583815059, 8792009665, 8877689391])

# %%
fitbit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   ActivityDay               940 non-null    object
#  3   TotalSteps                940 non-null    int64
#  4   TotalDistance             940 non-null    float64
#  5   TrackerDistance           940 non-null    float64
#  6   LoggedActivitiesDistance  940 non-null    float64
#  7   VeryActiveDistance        940 non-null    float64
#  8   ModeratelyActiveDistance  940 non-null    float64
#  9   LightActiveDistance       940 non-null    float64
#  10  SedentaryActiveDistance   940 non-null    float64
#  11  VeryActiveMinutes         940 non-null    int64
#  12  FairlyActiveMinutes       940 non-null    int64
#  13  LightlyActiveMinutes      940 non-null    int64
#  14  SedentaryMinutes          940 non-null    int64
#  15  Calories                  940 non-null    int64
#  16  Unnamed: 16               0 non-null      float64
#  17  Unnamed: 17               940 non-null    object
# dtypes: float64(8), int64(7), object(3)
# memory usage: 132.3+ KB

# %%
fitbit_df.head()
# Out:
#            Id ActivityDate ActivityDay  TotalSteps  TotalDistance  \
# 0  1503960366    4/12/2016         Tue       13162           8.50
# 1  1503960366    4/13/2016         Wed       10735           6.97
# 2  1503960366    4/14/2016         Thu       10460           6.74
# 3  1503960366    4/15/2016         Fri        9762           6.28
# 4  1503960366    4/16/2016         Sat       12669           8.16
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0             8.50                       0.0                1.88
# 1             6.97                       0.0                1.57
# 2             6.74                       0.0                2.44
# 3             6.28                       0.0                2.14
# 4             8.16                       0.0                2.71
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                      0.55                 6.06                      0.0
# 1                      0.69                 4.71                      0.0
# 2                      0.40                 3.91                      0.0
# 3                      1.26                 2.83                      0.0
# 4                      0.41                 5.04                      0.0
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                 25                   13                   328
# 1                 21                   19                   217
# 2                 30                   11                   181
# 3                 29                   34                   209
# 4                 36                   10                   221
#
#    SedentaryMinutes  Calories  Unnamed: 16 Unnamed: 17
# 0               728      1985          NaN         Tue
# 1               776      1797          NaN         Wed
# 2              1218      1776          NaN         Thu
# 3               726      1745          NaN         Fri
# 4               773      1863          NaN         Sat

# %%
fitbit_flushed_data = fitbit_df.loc[fitbit_df["TotalSteps"] > 500]

# %%
fitbit_flushed_data.count()
# Out:
# Id                          842
# ActivityDate                842
# ActivityDay                 842
# TotalSteps                  842
# TotalDistance               842
# TrackerDistance             842
# LoggedActivitiesDistance    842
# VeryActiveDistance          842
# ModeratelyActiveDistance    842
# LightActiveDistance         842
# SedentaryActiveDistance     842
# VeryActiveMinutes           842
# FairlyActiveMinutes         842
# LightlyActiveMinutes        842
# SedentaryMinutes            842
# Calories                    842
# Unnamed: 16                   0
# Unnamed: 17                 842
# dtype: int64

# %%
fitbit_zero_values = fitbit_df.loc[fitbit_df["TotalSteps"] < 500]

# %%
fitbit_zero_values.columns
# Out:
# Index(['Id', 'ActivityDate', 'ActivityDay', 'TotalSteps', 'TotalDistance',
#        'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Unnamed: 16',
#        'Unnamed: 17'],
#       dtype='object')

# %%
fitbit_zero_values[['TotalSteps', 'TotalDistance',
       'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance',
       'ModeratelyActiveDistance', 'LightActiveDistance',
       'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
       'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']] = 0
# Out:
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/3430058465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values[['TotalSteps', 'TotalDistance',

# %%
fitbit_zero_values.head()
# Out:
#              Id ActivityDate ActivityDay  TotalSteps  TotalDistance  \
# 30   1503960366    5/12/2016         Thu           0              0
# 99   1844505072    4/19/2016         Tue           0              0
# 100  1844505072    4/20/2016         Wed           0              0
# 104  1844505072    4/24/2016         Sun           0              0
# 105  1844505072    4/25/2016         Mon           0              0
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 30                 0                         0                   0
# 99                 0                         0                   0
# 100                0                         0                   0
# 104                0                         0                   0
# 105                0                         0                   0
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 30                          0                    0                        0
# 99                          0                    0                        0
# 100                         0                    0                        0
# 104                         0                    0                        0
# 105                         0                    0                        0
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 30                   0                    0                     0
# 99                   0                    0                     0
# 100                  0                    0                     0
# 104                  0                    0                     0
# 105                  0                    0                     0
#
#      SedentaryMinutes  Calories  Unnamed: 16 Unnamed: 17
# 30                  0         0          NaN         Thu
# 99                  0         0          NaN         Tue
# 100                 0         0          NaN         Wed
# 104                 0         0          NaN         Sun
# 105                 0         0          NaN         Mon

# %%
fitbit_zero_values.TotalSteps = fitbit_flushed_data.TotalSteps.mean()
fitbit_zero_values.TotalDistance = fitbit_flushed_data.TotalDistance.mean()
fitbit_zero_values.TrackerDistance = fitbit_flushed_data.TrackerDistance.mean()
fitbit_zero_values.LoggedActivitiesDistance = fitbit_flushed_data.LoggedActivitiesDistance.mean()
fitbit_zero_values.VeryActiveDistance = fitbit_flushed_data.VeryActiveDistance.mean()
fitbit_zero_values.ModeratelyActiveDistance = fitbit_flushed_data.ModeratelyActiveDistance.mean()
fitbit_zero_values.LightActiveDistance = fitbit_flushed_data.LightActiveDistance.mean()
fitbit_zero_values.SedentaryActiveDistance = fitbit_flushed_data.SedentaryActiveDistance.mean()
fitbit_zero_values.VeryActiveMinutes = fitbit_flushed_data.VeryActiveMinutes.mean()
fitbit_zero_values.FairlyActiveMinutes = fitbit_flushed_data.FairlyActiveMinutes.mean()
fitbit_zero_values.LightlyActiveMinutes = fitbit_flushed_data.LightlyActiveMinutes.mean()
fitbit_zero_values.SedentaryMinutes = fitbit_flushed_data.SedentaryMinutes.mean()
fitbit_zero_values.Calories = fitbit_flushed_data.Calories.mean()
# Out:
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.TotalSteps = fitbit_flushed_data.TotalSteps.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.TotalDistance = fitbit_flushed_data.TotalDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.TrackerDistance = fitbit_flushed_data.TrackerDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.LoggedActivitiesDistance = fitbit_flushed_data.LoggedActivitiesDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.VeryActiveDistance = fitbit_flushed_data.VeryActiveDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.ModeratelyActiveDistance = fitbit_flushed_data.ModeratelyActiveDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.LightActiveDistance = fitbit_flushed_data.LightActiveDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.SedentaryActiveDistance = fitbit_flushed_data.SedentaryActiveDistance.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.VeryActiveMinutes = fitbit_flushed_data.VeryActiveMinutes.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.FairlyActiveMinutes = fitbit_flushed_data.FairlyActiveMinutes.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.LightlyActiveMinutes = fitbit_flushed_data.LightlyActiveMinutes.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.SedentaryMinutes = fitbit_flushed_data.SedentaryMinutes.mean()
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1728019327.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitbit_zero_values.Calories = fitbit_flushed_data.Calories.mean()

# %%
fitbit_flushed_data = fitbit_df.drop(fitbit_df[fitbit_df['TotalSteps'] < 500].index)

# %%
fitbit_flushed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 939
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        842 non-null    int64
#  1   ActivityDate              842 non-null    object
#  2   ActivityDay               842 non-null    object
#  3   TotalSteps                842 non-null    int64
#  4   TotalDistance             842 non-null    float64
#  5   TrackerDistance           842 non-null    float64
#  6   LoggedActivitiesDistance  842 non-null    float64
#  7   VeryActiveDistance        842 non-null    float64
#  8   ModeratelyActiveDistance  842 non-null    float64
#  9   LightActiveDistance       842 non-null    float64
#  10  SedentaryActiveDistance   842 non-null    float64
#  11  VeryActiveMinutes         842 non-null    int64
#  12  FairlyActiveMinutes       842 non-null    int64
#  13  LightlyActiveMinutes      842 non-null    int64
#  14  SedentaryMinutes          842 non-null    int64
#  15  Calories                  842 non-null    int64
#  16  Unnamed: 16               0 non-null      float64
#  17  Unnamed: 17               842 non-null    object
# dtypes: float64(8), int64(7), object(3)
# memory usage: 125.0+ KB

# %%
fitbit_flushed_data.VeryActiveDistance.describe()
# Out:
# count    842.00000
# mean       1.67753
# std        2.75685
# min        0.00000
# 25%        0.00000
# 50%        0.47000
# 75%        2.32500
# max       21.92000
# Name: VeryActiveDistance, dtype: float64

# %%
fitbit_mean_data = pd.merge(fitbit_flushed_data, fitbit_zero_values, how='outer')
# Out:
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_74075/1498117699.py:1: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   fitbit_mean_data = pd.merge(fitbit_flushed_data, fitbit_zero_values, how='outer')

# %%
fitbit_mean_data.to_csv('fitbit_mean_data_cleaned.csv', index=True)

# %%
fitbit_flushed_data.to_csv('fitbit_flushed_data.csv', index=True)

# %%
fitbit_mean_data.loc[fitbit_df["VeryActiveDistance"] > 0]
# Out:
#              Id ActivityDate ActivityDay   TotalSteps  TotalDistance  \
# 0    1503960366    4/12/2016         Tue  13162.00000       8.500000
# 1    1503960366    4/13/2016         Wed  10735.00000       6.970000
# 2    1503960366    4/14/2016         Thu  10460.00000       6.740000
# 3    1503960366    4/15/2016         Fri   9762.00000       6.280000
# 4    1503960366    4/16/2016         Sat  12669.00000       8.160000
# ..          ...          ...         ...          ...            ...
# 935  8792009665     5/6/2016         Fri   8523.33848       6.126247
# 936  8792009665     5/7/2016         Sat   8523.33848       6.126247
# 937  8792009665     5/8/2016         Sun   8523.33848       6.126247
# 938  8792009665     5/9/2016         Mon   8523.33848       6.126247
# 939  8792009665    5/10/2016         Tue   8523.33848       6.126247
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0           8.500000                  0.000000             1.88000
# 1           6.970000                  0.000000             1.57000
# 2           6.740000                  0.000000             2.44000
# 3           6.280000                  0.000000             2.14000
# 4           8.160000                  0.000000             2.71000
# ..               ...                       ...                 ...
# 935         6.110226                  0.120761             1.67753
# 936         6.110226                  0.120761             1.67753
# 937         6.110226                  0.120761             1.67753
# 938         6.110226                  0.120761             1.67753
# 939         6.110226                  0.120761             1.67753
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                    0.550000             6.060000                 0.000000
# 1                    0.690000             4.710000                 0.000000
# 2                    0.400000             3.910000                 0.000000
# 3                    1.260000             2.830000                 0.000000
# 4                    0.410000             5.040000                 0.000000
# ..                        ...                  ...                      ...
# 935                  0.633492             3.727494                 0.001793
# 936                  0.633492             3.727494                 0.001793
# 937                  0.633492             3.727494                 0.001793
# 938                  0.633492             3.727494                 0.001793
# 939                  0.633492             3.727494                 0.001793
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0            25.000000             13.00000            328.000000
# 1            21.000000             19.00000            217.000000
# 2            30.000000             11.00000            181.000000
# 3            29.000000             34.00000            209.000000
# 4            36.000000             10.00000            221.000000
# ..                 ...                  ...                   ...
# 935          23.585511             15.12114            215.024941
# 936          23.585511             15.12114            215.024941
# 937          23.585511             15.12114            215.024941
# 938          23.585511             15.12114            215.024941
# 939          23.585511             15.12114            215.024941
#
#      SedentaryMinutes    Calories  Unnamed: 16 Unnamed: 17
# 0           728.00000  1985.00000          NaN         Tue
# 1           776.00000  1797.00000          NaN         Wed
# 2          1218.00000  1776.00000          NaN         Thu
# 3           726.00000  1745.00000          NaN         Fri
# 4           773.00000  1863.00000          NaN         Sat
# ..                ...         ...          ...         ...
# 935         948.63658  2379.74228          NaN         Fri
# 936         948.63658  2379.74228          NaN         Sat
# 937         948.63658  2379.74228          NaN         Sun
# 938         948.63658  2379.74228          NaN         Mon
# 939         948.63658  2379.74228          NaN         Tue
#
# [527 rows x 18 columns]

# %%
fitbit_df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.210000                  0.240000
# 75%                    0.000000            2.052500                  0.800000
# max                    4.942142           21.920000                  6.480000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           940.000000               940.000000         940.000000
# mean              3.340819                 0.001606          21.164894
# std               2.040655                 0.007346          32.844803
# min               0.000000                 0.000000           0.000000
# 25%               1.945000                 0.000000           0.000000
# 50%               3.365000                 0.000000           4.000000
# 75%               4.782500                 0.000000          32.000000
# max              10.710000                 0.110000         210.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           940.000000            940.000000        940.000000
# mean             13.564894            192.812766        991.210638
# std              19.987404            109.174700        301.267437
# min               0.000000              0.000000          0.000000
# 25%               0.000000            127.000000        729.750000
# 50%               6.000000            199.000000       1057.500000
# 75%              19.000000            264.000000       1229.500000
# max             143.000000            518.000000       1440.000000
#
#           Calories  Unnamed: 16
# count   940.000000          0.0
# mean   2303.609574          NaN
# std     718.166862          NaN
# min       0.000000          NaN
# 25%    1828.500000          NaN
# 50%    2134.000000          NaN
# 75%    2793.250000          NaN
# max    4900.000000          NaN

# %%
fitbit_df.columns
# Out:
# Index(['Id', 'ActivityDate', 'ActivityDay', 'TotalSteps', 'TotalDistance',
#        'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Unnamed: 16',
#        'Unnamed: 17'],
#       dtype='object')

# %%
fitbit_df.drop('Unnamed: 16', axis=1, inplace=True)

# %%
fitbit_df.drop('Unnamed: 17', axis=1, inplace=True)

# %%
fitbit_df.columns
# Out:
# Index(['Id', 'ActivityDate', 'ActivityDay', 'TotalSteps', 'TotalDistance',
#        'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
fitbit_flushed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 939
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        842 non-null    int64
#  1   ActivityDate              842 non-null    object
#  2   ActivityDay               842 non-null    object
#  3   TotalSteps                842 non-null    int64
#  4   TotalDistance             842 non-null    float64
#  5   TrackerDistance           842 non-null    float64
#  6   LoggedActivitiesDistance  842 non-null    float64
#  7   VeryActiveDistance        842 non-null    float64
#  8   ModeratelyActiveDistance  842 non-null    float64
#  9   LightActiveDistance       842 non-null    float64
#  10  SedentaryActiveDistance   842 non-null    float64
#  11  VeryActiveMinutes         842 non-null    int64
#  12  FairlyActiveMinutes       842 non-null    int64
#  13  LightlyActiveMinutes      842 non-null    int64
#  14  SedentaryMinutes          842 non-null    int64
#  15  Calories                  842 non-null    int64
#  16  Unnamed: 16               0 non-null      float64
#  17  Unnamed: 17               842 non-null    object
# dtypes: float64(8), int64(7), object(3)
# memory usage: 125.0+ KB

# %%
dave_data_df.head()
# Out:
#    Date:   StepCount  TotalDistance  VeryActiveMinutes  VeryActiveMinutes/2  \
# 0  1/1/23      22278          10.91                  0                  0.0
# 1  1/2/23      18981           9.31                  0                  0.0
# 2  1/3/23      21779          10.68                  0                  0.0
# 3  1/4/23       9408           4.56                  0                  0.0
# 4  1/5/23      22051          12.66                 64                 32.0
#
#    Calories
# 0      4154
# 1      3906
# 2      4115
# 3      3348
# 4      5148

# %%
dave_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date:                212 non-null    object
#  1   StepCount            212 non-null    int64
#  2   TotalDistance        212 non-null    float64
#  3   VeryActiveMinutes    212 non-null    int64
#  4   VeryActiveMinutes/2  212 non-null    float64
#  5   Calories             212 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 10.1+ KB

# %%
dave_data_df.describe()
# Out:
#            StepCount  TotalDistance  VeryActiveMinutes  VeryActiveMinutes/2  \
# count     212.000000     212.000000         212.000000           212.000000
# mean    15250.783019       7.601024          29.018868            14.509434
# std      9471.392389       2.963896          36.391495            18.195747
# min      6461.000000       3.170000           0.000000             0.000000
# 25%     11210.250000       5.672500           0.000000             0.000000
# 50%     13705.500000       6.930000          14.000000             7.000000
# 75%     17089.500000       8.552500          48.000000            24.000000
# max    131911.000000      23.450000         186.000000            93.000000
#
#           Calories
# count   212.000000
# mean   3886.419811
# std     557.990571
# min    2993.000000
# 25%    3507.000000
# 50%    3737.500000
# 75%    4124.250000
# max    6577.000000
